# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as plt
import pandas as pd
df=pd.read_csv("clevelanda (1).csv")
df
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(df['age'], df['chol'])
plt.xlabel('age')
plt.ylabel('chol')
plt.show()

# %%
plt.plot(df['slope'],df["cp"])
plt.title("line plot between slope and cp")
plt.xlabel("age")
plt.ylabel("slope")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,5,7,8,10]
plt.plot(x,y,color='green')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,5,7,8,10]
plt.plot(x,y,linestyle="dashed")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,5,7,8,10]
plt.plot(x,y,marker="*")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,5,7,8,10]
plt.plot(x,y,linewidth="0.5",color="green",marker="*")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[10000,40000,10000,20000,50000,5000]
plt.plot(x,y,linestyle="dashed",color="green",marker="o")
plt.title("saving amounts by month")
plt.xlabel("months")
plt.ylabel("saving amounts")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[10000,40000,10000,20000,50000,5000]
plt.bar(x,y,color="lightgreen")
plt.title("saving amounts by month")
plt.xlabel("months")
plt.ylabel("saving amounts")
plt.show()

# %%
ages=[20,30,40,10,30,30,40,10,60,60]
b=[10,40,70,100]
#bins are the intervals for grouping the data
plt.hist(ages,bins=b,color="orange",edgecolor="green")
plt.xlabel("ages")
plt.ylabel("b")
plt.grid(True)
plt.show()

# %%
x=['python','java','c','javascript']
y=[25,40,5,30]
plt.pie(y,labels=x,autopct='%1.1f%%')
plt.title("pie chart")
plt.legend(loc="upper left")
plt.show()

# %%
plt.scatter(df['age'],df['chol'],color="green",edgecolor="orange")
plt.title("pie chart")
plt.show()
